# %% [markdown]
# Este notebook se usará para la creación del proyecto del último curso del Certificado profesional de Ciencia de Datos de IBM

# %%
import pandas as pd
import numpy as np

# %%
print("¡Hola, Proyecto Final del Curso!")
# Out:
# ¡Hola, Proyecto Final del Curso!
